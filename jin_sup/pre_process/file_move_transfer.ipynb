# %% [markdown]
# # 비디오 파일 전체 음성파일로 변환

# %%
# import os
# import subprocess

# root_folder = "data"
# output_root = "audios"
# os.makedirs(output_root, exist_ok=True)

# for dirpath, _, filenames in os.walk(root_folder):
#     if "movie" in dirpath:
#         for file in filenames:
#             if file.endswith(".m2ts"):
#                 input_path = os.path.join(dirpath,file)
               
#                 relative_path = os.path.relpath(dirpath, root_folder)
#                 output_dir = os.path.join(output_root, relative_path)
#                 os.makedirs(output_dir,exist_ok = True)

#                 output_path = os.path.join(output_dir, os.path.splitext(file)[0] + ".wav")
#                 result = subprocess.run([
#                     r"C:\ffmpeg\bin\ffmpeg.exe",
#                     "-i", input_path,
#                     "-vn", "-acodec", "pcm_s16le", "-ar", "16000", "-ac", "1",
#                     output_path
#                 ], capture_output=True, text=True)
               
#                 print("stdout:", result.stdout)
#                 print("stderr:", result.stderr)
# Out:
# Exception in thread Thread-4 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-6 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-8 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# Exception in thread Thread-10 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-12 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-14 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# Exception in thread Thread-16 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-18 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-20 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-22 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-24 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# stdout:
# stderr: None
# stdout:
# stderr: None
# Exception in thread Thread-26 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-28 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-30 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# Exception in thread Thread-32 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-34 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-36 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# Thread-38 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-40 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-42 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# Thread-44 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-46 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-48 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-50 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-52 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-54 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-56 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-58 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-60 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-62 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-64 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-66 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-68 (_readerthread)
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# :
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-70 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-72 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-74 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-76 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-78 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# Exception in thread Thread-80 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-82 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-84 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-86 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# Exception in thread Thread-88 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-90 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-92 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# Thread-94 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-96 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-98 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-100 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-102 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-104 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-106 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-108 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-110 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-112 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# Exception in thread Thread-114 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-116 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1547: illegal multibyte sequence
# Exception in thread Thread-118 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
# ...
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1549: illegal multibyte sequence
# Exception in thread Thread-7844 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1549: illegal multibyte sequence
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# Exception in thread Thread-7846 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1549: illegal multibyte sequence
# Exception in thread Thread-7848 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1549: illegal multibyte sequence
# Exception in thread Thread-7850 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1549: illegal multibyte sequence
# Exception in thread Thread-7852 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1549: illegal multibyte sequence
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# Exception in thread Thread-7854 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1549: illegal multibyte sequence
# Exception in thread Thread-7856 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1549: illegal multibyte sequence
# Exception in thread Thread-7858 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1549: illegal multibyte sequence
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# Exception in thread Thread-7860 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1549: illegal multibyte sequence
# Exception in thread Thread-7862 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1549: illegal multibyte sequence
# Exception in thread Thread-7864 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1549: illegal multibyte sequence
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# Exception in thread Thread-7866 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1549: illegal multibyte sequence
# Exception in thread Thread-7868 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1549: illegal multibyte sequence
# Exception in thread Thread-7870 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1549: illegal multibyte sequence
# Exception in thread Thread-7872 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "c:\PythonProject\aug-08month_project5\.venv\lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\user\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py", line 1515, in _readerthread
#     buffer.append(fh.read())
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xeb in position 1549: illegal multibyte sequence
# stdout:
# stderr: None
# stdout:
# stderr: None
# stdout:
# stderr: None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 19
#      16 os.makedirs(output_dir,exist_ok = True)
#      18 output_path = os.path.join(output_dir, os.path.splitext(file)[0] + ".wav")
# ---> 19 result = subprocess.run([
#      20     r"C:\ffmpeg\bin\ffmpeg.exe",
#      21     "-i", input_path,
#      22     "-vn", "-acodec", "pcm_s16le", "-ar", "16000", "-ac", "1",
#      23     output_path
#      24 ], capture_output=True, text=True)
#      26 print("stdout:", result.stdout)
#      27 print("stderr:", result.stderr)
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py:1154, in Popen.communicate(self, input, timeout)
#    1151     endtime = None
#    1153 try:
# -> 1154     stdout, stderr = self._communicate(input, endtime, timeout)
#    1155 except KeyboardInterrupt:
#    1156     # https://bugs.python.org/issue25942
#    1157     # See the detailed comment in .wait().
#    1158     if timeout is not None:
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\subprocess.py:1544, in Popen._communicate(self, input, endtime, orig_timeout)
#    1540 # Wait for the reader threads, or time out.  If we time out, the
#    1541 # threads remain reading and the fds left open in case the user
#    1542 # calls communicate again.
#    1543 if self.stdout is not None:
# -> 1544     self.stdout_thread.join(self._remaining_time(endtime))
#    1545     if self.stdout_thread.is_alive():
#    1546         raise TimeoutExpired(self.args, orig_timeout)
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.18-windows-x86_64-none\lib\threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:

# %% [markdown]
# # 이미지 파일 복사

# %%
# import os
# import subprocess
# import shutil
#
# root_folder = "data"
# output_root = "images"
#
# os.makedirs(output_root, exist_ok=True)
#
# for dirpath, _, filenames in os.walk(root_folder):
#     if "picture" in dirpath:
#         for file in filenames:
#             if file.endswith(".JPG"):
#                 input_path = os.path.join(dirpath,file)
#                 relative_path = os.path.relpath(dirpath, root_folder)
#                 print(input_path)
#                 output_dir = os.path.join(output_root, relative_path)
#
#                 os.makedirs(output_dir,exist_ok = True)
#                 output_path = os.path.join(output_dir, file)
#                 shutil.copy2(input_path, output_path)
#               
#                 print("입력:", input_path)
#                 print("출력:", output_path)
