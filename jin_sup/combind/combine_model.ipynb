# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from jin_sup.combind.image.DepressionClassifier import load_model
#       4 load_model()
#
# ModuleNotFoundError: No module named 'jin_sup'
